# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:\Users\Yunita Elisabet\OneDrive\Dokumen\semester 4\citra digital\tcinta.jpg")

# %%
plt.imshow (img)

# %%
cv2.rectangle (img, pt1 = (800, 470), pt2 = (980, 530), color = (255, 0, 0), thickness = 5)
plt.imshow(img)

# %%
cv2.circle(img, center = (950, 50), radius = 50,color = (0, 0, 255), thickness = 5) 
plt.imshow(img)

# %%
cv2.putText(img, text = "the Wall of Love",org = (250, 250),fontFace = cv2.FONT_HERSHEY_DUPLEX, fontScale = 2, color = (0, 255, 0), thickness = 2, lineType = cv2.LINE_AA) 
plt.imshow(img)
